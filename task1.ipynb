# %%
#Import data and libriaries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Downloads//AirQualityUCI.csv")

# %%
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/3/2004  18.00.00     2.6         1360     150.0      11.9
# 1  10/3/2004  19.00.00     2.0         1292     112.0       9.4
# 2  10/3/2004  20.00.00     2.2         1402      88.0       9.0
# 3  10/3/2004  21.00.00     2.2         1376      80.0       9.2
# 4  10/3/2004  22.00.00     1.6         1272      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692       1268.0
# 1            955      103          1174       92          1559        972.0
# 2            939      131          1140      114          1555       1074.0
# 3            948      172          1092      122          1584       1203.0
# 4            836      131          1205      116          1490       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# 4  11.2  59.6  0.7888

# %%
df.tail(2)
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9355  4/4/2005  13.00.00     2.1         1003    -200.0       9.5
# 9356  4/4/2005  14.00.00     2.2         1071    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH
# 9355        770.0  28.3  13.5  0.5139
# 9356        816.0  28.5  13.1  0.5028

# %%
df.shape
# Out:
# (9357, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   NOx(GT)        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9356 non-null   float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.033536  1048.816074  -159.066485     2.004628     894.432724
# std      79.096080   330.062067   139.800836    43.568942     342.491834
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max    1428.000000  2040.000000  1189.000000  1321.000000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.696484    794.910655    58.360372   1391.462755   974.900780
# std     257.434899    322.147362   128.153143    467.198972   456.996348
# min    -200.000000   -200.000000  -200.000000   -200.000000  -200.000000
# 25%      50.000000    637.000000    53.000000   1185.000000   700.000000
# 50%     141.000000    794.000000    96.000000   1446.000000   942.000000
# 75%     284.000000    960.000000   133.000000   1662.000000  1255.000000
# max    1479.000000   2683.000000  1779.000000   2775.000000  2523.000000
#
#                  T           RH           AH
# count  9357.000000  9357.000000  9356.000000
# mean      9.782430    39.479397    -6.838464
# std      43.206308    51.217345    38.978664
# min    -200.000000  -200.000000  -200.000000
# 25%      10.900000    34.100000     0.692250
# 50%      17.200000    48.500000     0.976800
# 75%      24.100000    61.900000     1.296300
# max      57.200000    88.700000     2.231000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   NOx(GT)        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9356 non-null   float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
#checking the null values
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               1
# dtype: int64

# %%
df = df.dropna()

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
df_col = df[['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']]

# %%
#Data visualization:
plt.rcParams['figure.figsize'] = [18, 16]
df_col.plot(kind="density", subplots=True, layout=(4,4), sharex=False, sharey=False)
plt.show()

# %%
#histpogram all varible
fig, axs = plt.subplots(1,2, figsize=(10,5))
df_col.plot(kind="hist", bins=30, density=True, alpha=0.7, ax=axs[0])
axs[0].set_title('Histogram of numeric variables')
df_col.plot(kind="hist", bins=30, density=True, alpha=0.7, stacked=True, ax=axs[1])
axs[1].set_title('Histogram of numeric variables (stacked)');

# %%
df.groupby('Date')['CO(GT)'].max().sort_values(ascending=False).head()
# Out:
# Date
# 2004-11-23    11.9
# 2004-11-17    10.2
# 2004-11-26    10.1
# 2004-12-13     9.9
# 2004-10-26     9.5
# Name: CO(GT), dtype: float64

# %%
df3 =df.set_index('Date').resample("Y")["CO(GT)"].max()
df3.head()
# Out:
# Date
# 2004-12-31    11.9
# 2005-12-31     8.7
# Freq: A-DEC, Name: CO(GT), dtype: float64

# %%
df.groupby('Date')['NOx(GT)'].max().sort_values(ascending=False).head()
# Out:
# Date
# 2004-12-13    1479
# 2004-11-26    1389
# 2004-11-23    1389
# 2004-11-22    1345
# 2004-12-14    1310
# Name: NOx(GT), dtype: int64

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9356.000000  9356.000000  9356.000000  9356.000000    9356.000000
# mean    -34.189803  1048.949551  -159.085720     1.863649     894.549701
# std      77.642400   329.827059   139.795924    41.381950     342.323158
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9356.000000   9356.000000  9356.000000   9356.000000  9356.000000
# mean    168.656370    795.016994    58.176464   1391.438221   975.002993
# std     257.419412    322.000303   126.919176    467.217915   456.913799
# min    -200.000000   -200.000000  -200.000000   -200.000000  -200.000000
# 25%      50.000000    637.000000    53.000000   1185.000000   700.000000
# 50%     141.000000    794.000000    96.000000   1446.000000   942.000000
# 75%     284.000000    960.000000   133.000000   1662.000000  1255.000000
# max    1479.000000   2683.000000   340.000000   2775.000000  2523.000000
#
#                  T           RH           AH
# count  9356.000000  9356.000000  9356.000000
# mean      9.777362    39.483487    -6.838464
# std      43.205836    51.218555    38.978664
# min    -200.000000  -200.000000  -200.000000
# 25%      10.900000    34.100000     0.692250
# 50%      17.200000    48.550000     0.976800
# 75%      24.100000    61.900000     1.296300
# max      44.600000    88.700000     2.231000

# %%
corr = df_col.corr()
corr
# Out:
#                  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# CO(GT)         1.000000     0.041687  0.128316 -0.031281       0.030220
# PT08.S1(CO)    0.041687     1.000000  0.170056  0.852701       0.933092
# NMHC(GT)       0.128316     0.170056  1.000000  0.037338       0.110152
# C6H6(GT)      -0.031281     0.852701  0.037338  1.000000       0.767444
# PT08.S2(NMHC)  0.030220     0.933092  0.110152  0.767444       1.000000
# NOx(GT)        0.526310     0.278219 -0.004473 -0.001104       0.331527
# PT08.S3(NOx)  -0.090184     0.087124  0.048798  0.512253      -0.073572
# NO2(GT)        0.670975     0.154324  0.103267 -0.010895       0.176812
# PT08.S4(NO2)  -0.073555     0.845137  0.162713  0.774670       0.874776
# PT08.S5(O3)    0.080661     0.892419  0.101241  0.641341       0.909889
# T             -0.068909     0.754874 -0.000003  0.971378       0.669055
# RH            -0.048160     0.745390  0.008295  0.925062       0.585809
# AH            -0.045856     0.764933  0.012507  0.984558       0.646600
#
#                 NOx(GT)  PT08.S3(NOx)   NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# CO(GT)         0.526310     -0.090184  0.670975     -0.073555     0.080661
# PT08.S1(CO)    0.278219      0.087124  0.154324      0.845137     0.892419
# NMHC(GT)      -0.004473      0.048798  0.103267      0.162713     0.101241
# C6H6(GT)      -0.001104      0.512253 -0.010895      0.774670     0.641341
# PT08.S2(NMHC)  0.331527     -0.073572  0.176812      0.874776     0.909889
# NOx(GT)        1.000000     -0.436265  0.817098      0.035678     0.462205
# PT08.S3(NOx)  -0.436265      1.000000 -0.256466      0.122812    -0.208776
# NO2(GT)        0.817098     -0.256466  1.000000     -0.021999     0.253830
# PT08.S4(NO2)   0.035678      0.122812 -0.021999      1.000000     0.723669
# PT08.S5(O3)    0.462205     -0.208776  0.253830      0.723669     1.000000
# T             -0.138436      0.588148 -0.084078      0.755071     0.503724
# RH            -0.052962      0.573600 -0.081248      0.640704     0.524962
# AH            -0.095826      0.621657 -0.060408      0.691922     0.519493
#
#                       T        RH        AH
# CO(GT)        -0.068909 -0.048160 -0.045856
# PT08.S1(CO)    0.754874  0.745390  0.764933
# NMHC(GT)      -0.000003  0.008295  0.012507
# C6H6(GT)       0.971378  0.925062  0.984558
# PT08.S2(NMHC)  0.669055  0.585809  0.646600
# NOx(GT)       -0.138436 -0.052962 -0.095826
# PT08.S3(NOx)   0.588148  0.573600  0.621657
# NO2(GT)       -0.084078 -0.081248 -0.060408
# PT08.S4(NO2)   0.755071  0.640704  0.691922
# PT08.S5(O3)    0.503724  0.524962  0.519493
# T              1.000000  0.885911  0.981001
# RH             0.885911  1.000000  0.943995
# AH             0.981001  0.943995  1.000000

# %%
plt.figure(figsize=(12,10))
ax = sns.heatmap(corr, annot=True, linewidth=0.5, cmap='RdBu_r', vmax=.8)
ax.set_ylim(sorted(ax.get_xlim(), reverse=True))

plt.show()

# %%
#RH variable analysis
fig = plt.figure(figsize=(20,8))
sns.lineplot(x='Date', y='RH', data=df)
plt.xlabel('Next days')
plt.ylabel('Average value of Relative Humidity  - RH, %')
plt.title('Average value of Relative Humidity in next days');

# %%
#T variable analysis
df["T"].hist(bins = 40, figsize=(8,5), rwidth=0.9, color="green")
plt.xlabel("Temperature")
plt.ylabel("Frequenct")
plt.title("Temperature distribution");

# %%
fig = plt.figure(figsize=(6,4))
sns.boxplot(x=df['T']);

# %%
df_corr = df[['T', 'RH']]
df_corr.head()
# Out:
#       T    RH
# 0  13.6  48.9
# 1  13.3  47.7
# 2  11.9  54.0
# 3  11.0  60.0
# 4  11.2  59.6

# %%
corr = df_corr.corr()
corr
# Out:
#            T        RH
# T   1.000000  0.885911
# RH  0.885911  1.000000

# %%
df_air = df[['Date', 'Time', 'T', 'RH']]
df_air.head()
# Out:
#         Date      Time     T    RH
# 0 2004-10-03  18.00.00  13.6  48.9
# 1 2004-10-03  19.00.00  13.3  47.7
# 2 2004-10-03  20.00.00  11.9  54.0
# 3 2004-10-03  21.00.00  11.0  60.0
# 4 2004-10-03  22.00.00  11.2  59.6

# %%
fig = plt.figure(figsize=(6,4))
sns.boxplot(x=df_air ['RH']);

# %%
Q1 = df_air ['RH'].quantile(0.25)
Q3 = df_air ['RH'].quantile(0.75)
IQR = Q3 -Q1 
print(IQR)
# Out:
# 27.799999999999997

# %%
outliers_filter = (df_air ['RH'] < (Q1 - 3.0 * IQR)) |(df_air ['RH'] > (Q3 + 3.0 * IQR))
outliers_filter.head(2)
# Out:
# 0    False
# 1    False
# Name: RH, dtype: bool

# %%
no_outlier_filter = ~(outliers_filter).any(axis=0)
no_outlier_filter
# Out:
# False

# %%
data = df_air['RH'].values.reshape(-1, 1)

# %%
outliers_fraction = 0.01

# %%
from sklearn.ensemble import IsolationForest

# %%
model = IsolationForest(contamination=outliers_fraction)
model.fit(data) 
df_air['outlier'] = pd.Series(model.predict(data))
# Out:
# <ipython-input-35-394e5d27e6b2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_air['outlier'] = pd.Series(model.predict(data))

# %%
df_air.head()
# Out:
#         Date      Time     T    RH  outlier
# 0 2004-10-03  18.00.00  13.6  48.9      1.0
# 1 2004-10-03  19.00.00  13.3  47.7      1.0
# 2 2004-10-03  20.00.00  11.9  54.0      1.0
# 3 2004-10-03  21.00.00  11.0  60.0      1.0
# 4 2004-10-03  22.00.00  11.2  59.6      1.0

# %%
df2 = df[df['RH'] == -200]
df = df.drop(df2.index, axis=0)

# %%
df.head(2)
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0 2004-10-03  18.00.00     2.6         1360     150.0      11.9
# 1 2004-10-03  19.00.00     2.0         1292     112.0       9.4
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692       1268.0
# 1            955      103          1174       92          1559        972.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255

# %%
fig = plt.figure(figsize=(6,4))
sns.boxplot(x=df['RH']);

# %%
#split the data into tarina and test

# %%
from sklearn.model_selection import train_test_split

# %%
# linear regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lm=LinearRegression()

# %%
x=df[[ 'CO(GT)','C6H6(GT)','PT08.S2(NMHC)','NOx(GT)','PT08.S3(NOx)','NO2(GT)','PT08.S4(NO2)','PT08.S5(O3)','T','AH']]

# %%
y= df['RH']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33, random_state=42)

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = lm.predict(x_test)

# %%
print('accuracy of your prediction are',end=' ')
print(r2_score(y_test,prediction)*100,end='')
print('%')
# Out:
# accuracy of your prediction are 87.26868532490025%

# %%
#RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
prediction = forest.predict(x_test)

# %%
print('accuracy of your prediction are',end=' ')
print(r2_score(y_test,prediction)*100,end='')
print('%')
# Out:
# accuracy of your prediction are 99.8787846364426%

# %%
#KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=1)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
prediction = knn.predict(x_test)

# %%
print('accuracy of your prediction are',end=' ')
print(r2_score(y_test,prediction)*100,end='')
print('%')
# Out:
# accuracy of your prediction are 42.15296643583808%

# %%
from sklearn.model_selection import KFold
forest = RandomForestRegressor()
kfold_validation=KFold(10)

# %%
from sklearn.model_selection import cross_val_score

# %%
results=cross_val_score(forest,x,y,cv=kfold_validation)
print(results)
# Out:
# [0.99905911 0.99805512 0.99918573 0.99738112 0.99719152 0.99831943
#  0.99660675 0.99671603 0.99222989 0.99001587]

# %%
print(np.mean(results))
# Out:
# 0.9964760567482361

# %%
#Gridsearch Cross validation

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = RandomForestRegressor()
param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

# %%
 grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=5)

# %%
 grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
return grid.best_score_ , grid.best_params_
def RFR(X_train, X_test, y_train, y_test, best_params):
    from sklearn.ensemble import RandomForestRegressor
    estimator = RandomForestRegressor(n_jobs=-1).set_params(**best_params)
    estimator.fit(X_train,y_train)
    y_predict = estimator.predict(X_test)
    print "R2 score:",r2(y_test,y_predict)
    return y_test,y_predict
# Out:
#   File "<ipython-input-91-ddbac53954fd>", line 7
#     print "R2 score:",r2(y_test,y_predict)
#           ^
# SyntaxError: invalid syntax
